# %%
import os

# Use one GPU only
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";  # The GPU id to use, usually either "0" or "1";
os.environ["CUDA_VISIBLE_DEVICES"]="0";  # Do other imports now...

import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)

tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=23400)])


from tensorflow.keras.models import load_model
from mtcnn.mtcnn import MTCNN
from PIL import Image
import numpy as np
from os.path import isdir
from os import listdir

from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN
from numpy import savez_compressed

from numpy import load
from numpy import expand_dims
from numpy import asarray
import random

from numpy import load
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from sklearn.svm import SVC
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical


# develop a classifier for the 5 Celebrity Faces Dataset
from random import choice
from numpy import load
from numpy import expand_dims
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from sklearn.svm import SVC
from matplotlib import pyplot


## Check graphics cards memory usage
# !nvidia-smi
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Using TensorFlow backend.
# Thu May 14 20:20:06 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64       Driver Version: 440.64       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  TITAN RTX           Off  | 00000000:08:00.0 Off |                  N/A |
# | 41%   31C    P8     4W / 280W |     12MiB / 24220MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 207...  Off  | 00000000:43:00.0  On |                  N/A |
# | 41%   32C    P3    23W / 215W |   6733MiB /  7974MiB |     34%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    1      2048      G   /usr/lib/xorg/Xorg                            40MiB |
# |    1      2189      G   /usr/bin/gnome-shell                          49MiB |
# |    1      2922      G   /usr/lib/xorg/Xorg                           341MiB |
# |    1      3079      G   /usr/bin/gnome-shell                         286MiB |
# |    1     26155      C   /home/froi/anaconda3/bin/python             6009MiB |
# +-----------------------------------------------------------------------------+

# %%
# Pick our dataset
# dataset = 'data/Celeb1-A/10/'
dataset = 'data/Celeb1-A/1000/'

# Mean and std from training set
mean = 127.41816755496842
std =  63.643689073805

def extract_face(filename, detector, required_size=(160, 160)):
    # load image from file
    image = Image.open(filename)
    # convert to RGB, if needed
    image = image.convert('RGB')
    # convert to array
    pixels = asarray(image)

    # detect faces in the image
    results = detector.detect_faces(pixels)
    if len(results) == 0:
        return None
    
    # extract the bounding box from the first face
    x1, y1, width, height = results[0]['box']
    # bug fix
    x1, y1 = abs(x1), abs(y1)
    x2, y2 = x1 + width, y1 + height
    
    # extract the face
    face = pixels[y1:y2, x1:x2]
    # resize pixels to the model size
    image = Image.fromarray(face)
    image = image.resize(required_size)
    face_array = asarray(image)
    return face_array

# %% [markdown]
# ## Introduction
#
# This notebook loads a pre-trained facenet model using keras to do image recognition on a new dataset.
# The dataset we will use is a 1000-person subset of the Celeb1-A dataset.
#
# The remainder of this notebook is divided into the following sections.<br>
#
# <b>Important:</b> Unless you wish to rerun the preprocessing and embedding steps, you can skip straight to the training step by loading in the provided "embeddings.npz" file.
#
# * Preprocessing:
# This step takes a given dataset and uses the mtcnn library to extract portions of an image that contains only the face.  This step produces the "faces.npz" file.<br><br>
#
# * Embedding:
# This step takes the preprocessed dataset and runs it through the pre-trained facenet model to generate a 128-dimensional vector representing the image.  We can conceptually think of this as taking a high dimensional image and hashing it into a low dimensional vector.  This step produces the "embeddings.npz" file.<br><br>
#
# * Training:
# This step creates a simple Sequential model with a 1000-class softmax output corresponding to the 1000 identities in our dataset and trains it on the training set.<br><br>
#
# * Prediction:
# This step inspects the results of the prediction on the validation set.<br><br>

# %% [markdown]
# ## Preprocessing -- Extracting Faces
#
# This step crops the images so that only the portion of the image containing the face is returned.
# If no face is detected, return None.

# %%
# function for face detection with mtcnn


# MTCNN face detector is used to find the bounding box 
# of the face in the given image.
detector = MTCNN()

# Initialize model_enc to None.
# The model encoder is the pre-trained facenet model.
model_enc = None

# %%
# Given an image of a person, return only the portion of the image
# that is the face
def extract_face(filename, detector, required_size=(160, 160)):
    # load image from file
    image = Image.open(filename)
    # convert to RGB, if needed
    image = image.convert('RGB')
    # convert to array
    pixels = asarray(image)

    # detect faces in the image
    results = detector.detect_faces(pixels)
    if len(results) == 0:
        return None
    
    # extract the bounding box from the first face
    x1, y1, width, height = results[0]['box']
    # bug fix
    x1, y1 = abs(x1), abs(y1)
    x2, y2 = x1 + width, y1 + height
    
    # extract the face
    face = pixels[y1:y2, x1:x2]
    # resize pixels to the model size
    image = Image.fromarray(face)
    image = image.resize(required_size)
    face_array = asarray(image)
    return face_array

# load images and extract faces for all images in a directory
def load_faces(directory):
    faces = list()
    # enumerate files
    for filename in listdir(directory):
        # path
        path = directory + filename
        # get face
        face = extract_face(path, detector)
        
        if face is not None:
            # store
            faces.append(face)
    return faces

# Load in training or validation set
# Directory is expected to be something like: "data/Celeb1-A/1000/train"
def load_dataset(directory):
    X, y = list(), list()
    # enumerate folders, on per class
    
    for subdir in listdir(directory):
        # path
        path = directory + '/' + subdir + '/'
        # skip any files that might be in the dir
        
        if not isdir(path):
            continue
        # load all faces in the subdirectory

        faces = load_faces(path)
        # create labels
        labels = [subdir for _ in range(len(faces))]
        # summarize progress
        print('>loaded %d examples for class: %s' % (len(faces), subdir))
        # store
        X.extend(faces)
        y.extend(labels)
    return np.asarray(X), np.asarray(y)

# %%
# Load train and validation test sets
trainX, trainy = load_dataset(dataset + '/train')
testX, testy = load_dataset(dataset + 'val')
# Out:
# >loaded 21 examples for class: 365
# >loaded 8 examples for class: 785
# >loaded 17 examples for class: 774
# >loaded 11 examples for class: 159
# >loaded 19 examples for class: 97
# >loaded 16 examples for class: 718
# >loaded 1 examples for class: 177
# >loaded 18 examples for class: 580
# >loaded 2 examples for class: 536
# >loaded 19 examples for class: 557
# >loaded 16 examples for class: 497
# >loaded 11 examples for class: 245
# >loaded 11 examples for class: 954
# >loaded 10 examples for class: 299
# >loaded 15 examples for class: 932
# >loaded 21 examples for class: 147
# >loaded 1 examples for class: 470
# >loaded 12 examples for class: 836
# >loaded 2 examples for class: 237
# >loaded 18 examples for class: 133
# >loaded 1 examples for class: 169
# >loaded 19 examples for class: 49
# >loaded 7 examples for class: 701
# >loaded 18 examples for class: 491
# >loaded 4 examples for class: 738
# >loaded 3 examples for class: 791
# >loaded 18 examples for class: 215
# >loaded 21 examples for class: 21
# >loaded 12 examples for class: 541
# >loaded 18 examples for class: 186
# >loaded 16 examples for class: 974
# >loaded 1 examples for class: 615
# >loaded 10 examples for class: 704
# >loaded 18 examples for class: 770
# >loaded 13 examples for class: 856
# >loaded 18 examples for class: 849
# >loaded 15 examples for class: 983
# >loaded 20 examples for class: 416
# >loaded 8 examples for class: 280
# >loaded 20 examples for class: 389
# >loaded 21 examples for class: 981
# >loaded 20 examples for class: 276
# >loaded 14 examples for class: 57
# >loaded 13 examples for class: 950
# >loaded 2 examples for class: 929
# >loaded 4 examples for class: 590
# >loaded 21 examples for class: 494
# >loaded 11 examples for class: 747
# >loaded 4 examples for class: 640
# >loaded 17 examples for class: 945
# >loaded 20 examples for class: 984
# >loaded 18 examples for class: 842
# >loaded 11 examples for class: 175
# >loaded 2 examples for class: 663
# >loaded 20 examples for class: 462
# >loaded 5 examples for class: 795
# >loaded 16 examples for class: 48
# >loaded 21 examples for class: 986
# >loaded 19 examples for class: 598
# >loaded 11 examples for class: 498
# >loaded 12 examples for class: 966
# >loaded 20 examples for class: 376
# >loaded 11 examples for class: 120
# >loaded 16 examples for class: 422
# >loaded 14 examples for class: 624
# >loaded 4 examples for class: 715
# >loaded 14 examples for class: 336
# >loaded 2 examples for class: 810
# >loaded 4 examples for class: 75
# >loaded 14 examples for class: 532
# >loaded 20 examples for class: 587
# >loaded 15 examples for class: 941
# >loaded 16 examples for class: 866
# >loaded 14 examples for class: 642
# >loaded 13 examples for class: 667
# >loaded 14 examples for class: 900
# >loaded 21 examples for class: 650
# >loaded 14 examples for class: 501
# >loaded 9 examples for class: 720
# >loaded 17 examples for class: 549
# >loaded 16 examples for class: 7
# >loaded 15 examples for class: 308
# >loaded 4 examples for class: 131
# >loaded 17 examples for class: 288
# >loaded 19 examples for class: 311
# >loaded 11 examples for class: 847
# >loaded 14 examples for class: 979
# >loaded 21 examples for class: 661
# >loaded 9 examples for class: 91
# >loaded 15 examples for class: 33
# >loaded 17 examples for class: 825
# >loaded 21 examples for class: 539
# >loaded 20 examples for class: 458
# >loaded 4 examples for class: 360
# >loaded 14 examples for class: 451
# >loaded 16 examples for class: 415
# >loaded 20 examples for class: 784
# >loaded 13 examples for class: 10
# >loaded 2 examples for class: 832
# >loaded 14 examples for class: 802
# >loaded 2 examples for class: 456
# >loaded 1 examples for class: 725
# >loaded 17 examples for class: 896
# >loaded 18 examples for class: 907
# >loaded 17 examples for class: 158
# >loaded 17 examples for class: 3
# >loaded 2 examples for class: 882
# >loaded 18 examples for class: 730
# >loaded 14 examples for class: 746
# >loaded 16 examples for class: 117
# >loaded 14 examples for class: 511
# >loaded 9 examples for class: 435
# >loaded 13 examples for class: 407
# >loaded 18 examples for class: 768
# >loaded 1 examples for class: 912
# >loaded 14 examples for class: 196
# >loaded 17 examples for class: 689
# >loaded 16 examples for class: 86
# >loaded 2 examples for class: 982
# >loaded 15 examples for class: 450
# >loaded 20 examples for class: 775
# >loaded 20 examples for class: 145
# >loaded 21 examples for class: 992
# >loaded 20 examples for class: 374
# >loaded 18 examples for class: 180
# >loaded 9 examples for class: 554
# >loaded 4 examples for class: 144
# >loaded 11 examples for class: 221
# >loaded 20 examples for class: 116
# >loaded 18 examples for class: 764
# >loaded 19 examples for class: 442
# >loaded 21 examples for class: 987
# >loaded 20 examples for class: 359
# >loaded 20 examples for class: 460
# >loaded 12 examples for class: 713
# >loaded 21 examples for class: 313
# >loaded 15 examples for class: 544
# >loaded 19 examples for class: 480
# >loaded 14 examples for class: 102
# >loaded 19 examples for class: 940
# >loaded 14 examples for class: 184
# >loaded 21 examples for class: 273
# >loaded 20 examples for class: 247
# >loaded 21 examples for class: 234
# >loaded 18 examples for class: 263
# >loaded 1 examples for class: 638
# >loaded 18 examples for class: 669
# >loaded 14 examples for class: 271
# >loaded 6 examples for class: 488
# >loaded 15 examples for class: 453
# >loaded 20 examples for class: 382
# >loaded 16 examples for class: 648
# >loaded 18 examples for class: 261
# >loaded 4 examples for class: 635
# >loaded 6 examples for class: 751
# >loaded 17 examples for class: 279
# >loaded 20 examples for class: 250
# >loaded 20 examples for class: 320
# >loaded 7 examples for class: 639
# >loaded 19 examples for class: 706
# >loaded 16 examples for class: 874
# >loaded 18 examples for class: 172
# >loaded 19 examples for class: 96
# >loaded 11 examples for class: 109
# >loaded 19 examples for class: 222
# >loaded 14 examples for class: 884
# >loaded 12 examples for class: 324
# >loaded 14 examples for class: 62
# >loaded 20 examples for class: 79
# >loaded 14 examples for class: 379
# >loaded 16 examples for class: 489
# >loaded 18 examples for class: 335
# >loaded 21 examples for class: 23
# >loaded 19 examples for class: 322
# >loaded 9 examples for class: 681
# >loaded 14 examples for class: 325
# >loaded 20 examples for class: 256
# >loaded 14 examples for class: 685
# >loaded 21 examples for class: 871
# >loaded 16 examples for class: 716
# >loaded 15 examples for class: 579
# >loaded 14 examples for class: 233
# >loaded 17 examples for class: 156
# >loaded 20 examples for class: 798
# >loaded 18 examples for class: 163
# >loaded 14 examples for class: 743
# >loaded 20 examples for class: 599
# >loaded 21 examples for class: 59
# >loaded 10 examples for class: 314
# >loaded 21 examples for class: 468
# >loaded 14 examples for class: 921
# >loaded 17 examples for class: 167
# >loaded 16 examples for class: 898
# >loaded 13 examples for class: 789
# >loaded 16 examples for class: 500
# >loaded 1 examples for class: 111
# >loaded 16 examples for class: 53
# >loaded 1 examples for class: 478
# >loaded 16 examples for class: 530
# >loaded 2 examples for class: 223
# >loaded 4 examples for class: 2
# >loaded 13 examples for class: 399
# >loaded 13 examples for class: 493
# >loaded 19 examples for class: 731
# >loaded 14 examples for class: 428
# >loaded 21 examples for class: 403
# >loaded 15 examples for class: 786
# >loaded 10 examples for class: 682
# >loaded 14 examples for class: 452
# >loaded 21 examples for class: 47
# >loaded 14 examples for class: 88
# >loaded 16 examples for class: 596
# >loaded 21 examples for class: 343
# >loaded 16 examples for class: 137
# >loaded 16 examples for class: 644
# >loaded 16 examples for class: 509
# >loaded 19 examples for class: 439
# >loaded 2 examples for class: 712
# >loaded 21 examples for class: 404
# >loaded 9 examples for class: 71
# >loaded 2 examples for class: 630
# >loaded 17 examples for class: 58
# >loaded 7 examples for class: 908
# >loaded 19 examples for class: 174
# >loaded 20 examples for class: 674
# >loaded 14 examples for class: 285
# >loaded 20 examples for class: 955
# >loaded 12 examples for class: 732
# >loaded 9 examples for class: 540
# >loaded 13 examples for class: 225
# >loaded 20 examples for class: 782
# >loaded 20 examples for class: 370
# >loaded 17 examples for class: 548
# >loaded 19 examples for class: 413
# >loaded 21 examples for class: 676
# >loaded 18 examples for class: 622
# >loaded 11 examples for class: 792
# >loaded 12 examples for class: 591
# >loaded 14 examples for class: 933
# >loaded 16 examples for class: 229
# >loaded 16 examples for class: 927
# >loaded 14 examples for class: 938
# >loaded 14 examples for class: 362
# >loaded 16 examples for class: 195
# >loaded 21 examples for class: 363
# >loaded 21 examples for class: 14
# >loaded 20 examples for class: 251
# >loaded 13 examples for class: 29
# >loaded 12 examples for class: 808
# >loaded 2 examples for class: 566
# >loaded 2 examples for class: 267
# >loaded 20 examples for class: 55
# >loaded 6 examples for class: 812
# >loaded 18 examples for class: 459
# >loaded 20 examples for class: 239
# >loaded 19 examples for class: 113
# >loaded 15 examples for class: 771
# >loaded 9 examples for class: 695
# >loaded 12 examples for class: 757
# >loaded 16 examples for class: 106
# >loaded 14 examples for class: 296
# >loaded 18 examples for class: 521
# >loaded 16 examples for class: 963
# >loaded 14 examples for class: 90
# >loaded 9 examples for class: 816
# >loaded 14 examples for class: 684
# >loaded 17 examples for class: 895
# >loaded 21 examples for class: 31
# >loaded 21 examples for class: 665
# >loaded 20 examples for class: 446
# >loaded 20 examples for class: 818
# >loaded 17 examples for class: 528
# >loaded 11 examples for class: 178
# >loaded 14 examples for class: 728
# >loaded 15 examples for class: 888
# >loaded 16 examples for class: 721
# >loaded 20 examples for class: 278
# >loaded 10 examples for class: 897
# >loaded 17 examples for class: 364
# >loaded 21 examples for class: 199
# >loaded 14 examples for class: 297
# >loaded 21 examples for class: 394
# >loaded 16 examples for class: 455
# >loaded 8 examples for class: 127
# >loaded 21 examples for class: 492
# >loaded 7 examples for class: 838
# >loaded 1 examples for class: 513
# >loaded 14 examples for class: 162
# >loaded 20 examples for class: 779
# >loaded 16 examples for class: 41
# >loaded 18 examples for class: 859
# >loaded 20 examples for class: 524
# >loaded 21 examples for class: 82
# >loaded 20 examples for class: 776
# >loaded 19 examples for class: 843
# >loaded 2 examples for class: 813
# >loaded 16 examples for class: 854
# >loaded 15 examples for class: 13
# >loaded 16 examples for class: 887
# >loaded 16 examples for class: 926
# >loaded 13 examples for class: 378
# >loaded 19 examples for class: 787
# >loaded 16 examples for class: 218
# >loaded 2 examples for class: 346
# >loaded 7 examples for class: 398
# >loaded 1 examples for class: 356
# >loaded 5 examples for class: 298
# >loaded 8 examples for class: 340
# >loaded 14 examples for class: 51
# >loaded 3 examples for class: 219
# >loaded 12 examples for class: 864
# >loaded 13 examples for class: 611
# >loaded 16 examples for class: 6
# >loaded 18 examples for class: 561
# >loaded 14 examples for class: 811
# >loaded 21 examples for class: 978
# >loaded 20 examples for class: 471
# >loaded 16 examples for class: 834
# >loaded 1 examples for class: 469
# >loaded 19 examples for class: 527
# >loaded 13 examples for class: 680
# >loaded 16 examples for class: 672
# >loaded 19 examples for class: 461
# >loaded 1 examples for class: 526
# >loaded 21 examples for class: 289
# >loaded 18 examples for class: 814
# >loaded 14 examples for class: 344
# >loaded 13 examples for class: 454
# >loaded 8 examples for class: 42
# >loaded 2 examples for class: 200
# >loaded 19 examples for class: 87
# >loaded 16 examples for class: 824
# >loaded 21 examples for class: 735
# >loaded 20 examples for class: 226
# >loaded 18 examples for class: 205
# >loaded 14 examples for class: 841
# >loaded 10 examples for class: 136
# >loaded 11 examples for class: 342
# >loaded 14 examples for class: 93
# >loaded 19 examples for class: 107
# >loaded 19 examples for class: 425
# >loaded 16 examples for class: 652
# >loaded 14 examples for class: 84
# >loaded 11 examples for class: 629
# >loaded 14 examples for class: 994
# >loaded 2 examples for class: 641
# >loaded 17 examples for class: 646
# >loaded 7 examples for class: 571
# >loaded 13 examples for class: 270
# >loaded 21 examples for class: 894
# >loaded 20 examples for class: 373
# >loaded 21 examples for class: 318
# >loaded 21 examples for class: 975
# >loaded 1 examples for class: 76
# >loaded 7 examples for class: 754
# >loaded 20 examples for class: 631
# >loaded 18 examples for class: 375
# >loaded 13 examples for class: 310
# >loaded 14 examples for class: 275
# >loaded 13 examples for class: 793
# >loaded 13 examples for class: 585
# >loaded 19 examples for class: 542
# >loaded 20 examples for class: 155
# >loaded 15 examples for class: 400
# >loaded 17 examples for class: 881
# >loaded 21 examples for class: 801
# >loaded 10 examples for class: 474
# >loaded 17 examples for class: 148
# >loaded 17 examples for class: 357
# >loaded 3 examples for class: 9
# >loaded 10 examples for class: 484
# >loaded 14 examples for class: 645
# >loaded 11 examples for class: 805
# >loaded 14 examples for class: 860
# >loaded 7 examples for class: 683
# >loaded 14 examples for class: 287
# >loaded 20 examples for class: 961
# >loaded 14 examples for class: 913
# >loaded 21 examples for class: 220
# >loaded 14 examples for class: 366
# >loaded 20 examples for class: 361
# >loaded 14 examples for class: 625
# >loaded 19 examples for class: 388
# >loaded 18 examples for class: 835
# >loaded 18 examples for class: 620
# >loaded 2 examples for class: 920
# >loaded 21 examples for class: 122
# >loaded 21 examples for class: 565
# >loaded 19 examples for class: 138
# >loaded 1 examples for class: 307
# >loaded 20 examples for class: 393
# >loaded 14 examples for class: 437
# >loaded 19 examples for class: 128
# >loaded 16 examples for class: 819
# >loaded 13 examples for class: 697
# >loaded 21 examples for class: 94
# >loaded 14 examples for class: 892
# >loaded 7 examples for class: 440
# >loaded 15 examples for class: 70
# >loaded 20 examples for class: 132
# >loaded 14 examples for class: 134
# >loaded 19 examples for class: 327
# >loaded 21 examples for class: 114
# >loaded 18 examples for class: 135
# >loaded 6 examples for class: 823
# >loaded 21 examples for class: 679
# >loaded 14 examples for class: 517
# >loaded 18 examples for class: 123
# >loaded 9 examples for class: 809
# >loaded 16 examples for class: 383
# >loaded 2 examples for class: 304
# >loaded 19 examples for class: 214
# >loaded 12 examples for class: 282
# >loaded 14 examples for class: 972
# >loaded 21 examples for class: 924
# >loaded 14 examples for class: 870
# >loaded 21 examples for class: 659
# >loaded 19 examples for class: 486
# >loaded 13 examples for class: 531
# >loaded 4 examples for class: 777
# >loaded 13 examples for class: 350
# >loaded 7 examples for class: 286
# >loaded 7 examples for class: 411
# >loaded 1 examples for class: 255
# >loaded 5 examples for class: 828
# >loaded 19 examples for class: 603
# >loaded 21 examples for class: 499
# >loaded 11 examples for class: 617
# >loaded 14 examples for class: 967
# >loaded 21 examples for class: 510
# >loaded 19 examples for class: 176
# >loaded 15 examples for class: 760
# >loaded 20 examples for class: 826
# >loaded 14 examples for class: 964
# >loaded 19 examples for class: 230
# >loaded 13 examples for class: 392
# >loaded 21 examples for class: 209
# >loaded 12 examples for class: 628
# >loaded 21 examples for class: 873
# >loaded 13 examples for class: 790
# >loaded 10 examples for class: 937
# >loaded 21 examples for class: 988
# >loaded 16 examples for class: 414
# >loaded 4 examples for class: 546
# >loaded 14 examples for class: 552
# >loaded 21 examples for class: 85
# >loaded 9 examples for class: 543
# >loaded 9 examples for class: 976
# >loaded 5 examples for class: 601
# >loaded 16 examples for class: 151
# >loaded 7 examples for class: 161
# >loaded 18 examples for class: 448
# >loaded 14 examples for class: 934
# >loaded 21 examples for class: 397
# >loaded 10 examples for class: 150
# >loaded 7 examples for class: 355
# >loaded 15 examples for class: 857
# >loaded 21 examples for class: 993
# >loaded 2 examples for class: 717
# >loaded 14 examples for class: 18
# >loaded 14 examples for class: 268
# >loaded 20 examples for class: 904
# >loaded 16 examples for class: 696
# >loaded 18 examples for class: 262
# >loaded 14 examples for class: 890
# >loaded 20 examples for class: 886
# >loaded 21 examples for class: 348
# >loaded 2 examples for class: 723
# >loaded 20 examples for class: 153
# >loaded 19 examples for class: 419
# >loaded 17 examples for class: 584
# >loaded 17 examples for class: 654
# >loaded 4 examples for class: 572
# >loaded 11 examples for class: 443
# >loaded 21 examples for class: 235
# >loaded 21 examples for class: 334
# >loaded 20 examples for class: 260
# >loaded 16 examples for class: 77
# >loaded 21 examples for class: 56
# >loaded 14 examples for class: 533
# >loaded 16 examples for class: 67
# >loaded 20 examples for class: 104
# >loaded 19 examples for class: 593
# >loaded 21 examples for class: 38
# >loaded 20 examples for class: 846
# >loaded 14 examples for class: 197
# >loaded 14 examples for class: 589
# >loaded 20 examples for class: 146
# >loaded 18 examples for class: 688
# >loaded 19 examples for class: 923
# >loaded 10 examples for class: 381
# >loaded 14 examples for class: 903
# >loaded 10 examples for class: 850
# >loaded 16 examples for class: 607
# >loaded 19 examples for class: 868
# >loaded 20 examples for class: 476
# >loaded 20 examples for class: 965
# >loaded 17 examples for class: 12
# >loaded 16 examples for class: 46
# >loaded 17 examples for class: 258
# >loaded 20 examples for class: 745
# >loaded 20 examples for class: 323
# >loaded 14 examples for class: 5
# >loaded 18 examples for class: 796
# >loaded 16 examples for class: 129
# >loaded 7 examples for class: 761
# >loaded 18 examples for class: 686
# >loaded 16 examples for class: 519
# >loaded 14 examples for class: 253
# >loaded 11 examples for class: 766
# >loaded 4 examples for class: 736
# >loaded 20 examples for class: 577
# >loaded 14 examples for class: 692
# >loaded 7 examples for class: 670
# >loaded 21 examples for class: 142
# >loaded 3 examples for class: 711
# >loaded 14 examples for class: 872
# >loaded 14 examples for class: 368
# >loaded 21 examples for class: 65
# >loaded 5 examples for class: 1000
# >loaded 9 examples for class: 352
# >loaded 14 examples for class: 862
# >loaded 14 examples for class: 595
# >loaded 19 examples for class: 573
# >loaded 11 examples for class: 597
# >loaded 9 examples for class: 277
# >loaded 20 examples for class: 358
# >loaded 19 examples for class: 317
# >loaded 20 examples for class: 592
# >loaded 11 examples for class: 637
# >loaded 11 examples for class: 690
# >loaded 13 examples for class: 925
# >loaded 6 examples for class: 16
# >loaded 14 examples for class: 227
# >loaded 21 examples for class: 632
# >loaded 19 examples for class: 207
# >loaded 12 examples for class: 922
# >loaded 4 examples for class: 737
# >loaded 21 examples for class: 649
# >loaded 14 examples for class: 910
# >loaded 20 examples for class: 61
# >loaded 14 examples for class: 514
# >loaded 14 examples for class: 24
# >loaded 8 examples for class: 429
# >loaded 16 examples for class: 264
# >loaded 4 examples for class: 189
# >loaded 17 examples for class: 110
# >loaded 14 examples for class: 63
# >loaded 19 examples for class: 457
# >loaded 17 examples for class: 724
# >loaded 19 examples for class: 68
# >loaded 18 examples for class: 387
# >loaded 14 examples for class: 166
# >loaded 7 examples for class: 503
# >loaded 13 examples for class: 551
# >loaded 13 examples for class: 833
# >loaded 5 examples for class: 154
# >loaded 21 examples for class: 958
# >loaded 21 examples for class: 417
# >loaded 14 examples for class: 765
# >loaded 13 examples for class: 316
# >loaded 18 examples for class: 292
# >loaded 14 examples for class: 426
# >loaded 12 examples for class: 883
# >loaded 14 examples for class: 99
# >loaded 12 examples for class: 333
# >loaded 16 examples for class: 756
# >loaded 18 examples for class: 869
# >loaded 15 examples for class: 4
# >loaded 21 examples for class: 449
# >loaded 15 examples for class: 575
# >loaded 3 examples for class: 44
# >loaded 17 examples for class: 98
# >loaded 7 examples for class: 11
# >loaded 20 examples for class: 547
# >loaded 18 examples for class: 889
# >loaded 20 examples for class: 257
# >loaded 10 examples for class: 183
# >loaded 19 examples for class: 204
# >loaded 19 examples for class: 157
# >loaded 19 examples for class: 306
# >loaded 10 examples for class: 556
# >loaded 14 examples for class: 369
# >loaded 20 examples for class: 578
# >loaded 5 examples for class: 762
# >loaded 20 examples for class: 101
# >loaded 21 examples for class: 973
# >loaded 15 examples for class: 623
# >loaded 17 examples for class: 931
# >loaded 13 examples for class: 252
# >loaded 21 examples for class: 349
# >loaded 12 examples for class: 502
# >loaded 15 examples for class: 45
# >loaded 19 examples for class: 604
# >loaded 7 examples for class: 202
# >loaded 7 examples for class: 236
# >loaded 9 examples for class: 490
# >loaded 18 examples for class: 125
# >loaded 11 examples for class: 653
# >loaded 21 examples for class: 985
# >loaded 17 examples for class: 804
# >loaded 5 examples for class: 962
# >loaded 7 examples for class: 402
# >loaded 8 examples for class: 827
# >loaded 6 examples for class: 321
# >loaded 16 examples for class: 165
# >loaded 17 examples for class: 330
# >loaded 8 examples for class: 893
# >loaded 13 examples for class: 210
# >loaded 13 examples for class: 748
# >loaded 21 examples for class: 977
# >loaded 20 examples for class: 338
# >loaded 18 examples for class: 678
# >loaded 14 examples for class: 434
# >loaded 16 examples for class: 610
# >loaded 20 examples for class: 758
# >loaded 11 examples for class: 609
# >loaded 20 examples for class: 423
# >loaded 19 examples for class: 143
# >loaded 16 examples for class: 52
# >loaded 21 examples for class: 861
# >loaded 14 examples for class: 968
# >loaded 16 examples for class: 418
# >loaded 20 examples for class: 657
# >loaded 21 examples for class: 553
# >loaded 13 examples for class: 822
# >loaded 20 examples for class: 863
# >loaded 20 examples for class: 612
# >loaded 2 examples for class: 995
# >loaded 20 examples for class: 727
# >loaded 7 examples for class: 613
# >loaded 16 examples for class: 633
# >loaded 6 examples for class: 703
# >loaded 13 examples for class: 20
# >loaded 18 examples for class: 767
# >loaded 14 examples for class: 990
# >loaded 16 examples for class: 643
# >loaded 20 examples for class: 671
# >loaded 1 examples for class: 26
# >loaded 21 examples for class: 800
# >loaded 21 examples for class: 614
# >loaded 13 examples for class: 50
# >loaded 5 examples for class: 840
# >loaded 18 examples for class: 909
# >loaded 15 examples for class: 212
# >loaded 21 examples for class: 719
# >loaded 14 examples for class: 773
# >loaded 21 examples for class: 25
# >loaded 7 examples for class: 193
# >loaded 1 examples for class: 763
# >loaded 6 examples for class: 37
# >loaded 11 examples for class: 35
# >loaded 21 examples for class: 742
# >loaded 10 examples for class: 337
# >loaded 8 examples for class: 726
# >loaded 19 examples for class: 675
# >loaded 5 examples for class: 634
# >loaded 18 examples for class: 485
# >loaded 17 examples for class: 794
# >loaded 21 examples for class: 600
# >loaded 11 examples for class: 948
# >loaded 15 examples for class: 427
# >loaded 9 examples for class: 820
# >loaded 11 examples for class: 238
# >loaded 5 examples for class: 537
# >loaded 21 examples for class: 481
# >loaded 3 examples for class: 329
# >loaded 4 examples for class: 853
# >loaded 19 examples for class: 523
# >loaded 14 examples for class: 367
# >loaded 10 examples for class: 231
# >loaded 17 examples for class: 952
# >loaded 20 examples for class: 947
# >loaded 16 examples for class: 535
# >loaded 21 examples for class: 371
# >loaded 21 examples for class: 409
# >loaded 14 examples for class: 232
# >loaded 16 examples for class: 734
# >loaded 14 examples for class: 959
# >loaded 1 examples for class: 673
# >loaded 2 examples for class: 74
# >loaded 10 examples for class: 538
# >loaded 21 examples for class: 291
# >loaded 21 examples for class: 78
# >loaded 14 examples for class: 396
# >loaded 19 examples for class: 677
# >loaded 18 examples for class: 331
# >loaded 1 examples for class: 522
# >loaded 21 examples for class: 284
# >loaded 11 examples for class: 241
# >loaded 20 examples for class: 999
# >loaded 13 examples for class: 559
# >loaded 14 examples for class: 586
# >loaded 9 examples for class: 905
# >loaded 14 examples for class: 473
# >loaded 20 examples for class: 64
# >loaded 1 examples for class: 244
# >loaded 6 examples for class: 729
# >loaded 14 examples for class: 294
# >loaded 4 examples for class: 891
# >loaded 9 examples for class: 182
# >loaded 19 examples for class: 944
# >loaded 18 examples for class: 351
# >loaded 7 examples for class: 709
# >loaded 16 examples for class: 141
# >loaded 15 examples for class: 817
# >loaded 14 examples for class: 401
# >loaded 18 examples for class: 876
# >loaded 20 examples for class: 81
# >loaded 4 examples for class: 722
# >loaded 3 examples for class: 249
# >loaded 21 examples for class: 487
# >loaded 16 examples for class: 173
# >loaded 14 examples for class: 408
# >loaded 7 examples for class: 618
# >loaded 8 examples for class: 201
# >loaded 20 examples for class: 594
# >loaded 3 examples for class: 996
# >loaded 20 examples for class: 445
# >loaded 17 examples for class: 750
# >loaded 9 examples for class: 664
# >loaded 6 examples for class: 472
# >loaded 7 examples for class: 998
# >loaded 18 examples for class: 576
# >loaded 14 examples for class: 852
# >loaded 14 examples for class: 875
# >loaded 13 examples for class: 211
# >loaded 11 examples for class: 778
# >loaded 21 examples for class: 17
# >loaded 21 examples for class: 248
# >loaded 5 examples for class: 479
# >loaded 20 examples for class: 121
# >loaded 20 examples for class: 386
# >loaded 1 examples for class: 917
# >loaded 21 examples for class: 192
# >loaded 12 examples for class: 911
# >loaded 21 examples for class: 844
# >loaded 13 examples for class: 60
# >loaded 16 examples for class: 855
# >loaded 14 examples for class: 92
# >loaded 2 examples for class: 582
# >loaded 17 examples for class: 583
# >loaded 13 examples for class: 969
# >loaded 16 examples for class: 619
# >loaded 21 examples for class: 534
# >loaded 18 examples for class: 694
# >loaded 14 examples for class: 332
# >loaded 5 examples for class: 431
# >loaded 17 examples for class: 693
# >loaded 16 examples for class: 957
# >loaded 14 examples for class: 803
# >loaded 19 examples for class: 733
# >loaded 21 examples for class: 997
# >loaded 13 examples for class: 83
# >loaded 20 examples for class: 466
# >loaded 20 examples for class: 772
# >loaded 21 examples for class: 918
# >loaded 2 examples for class: 149
# >loaded 2 examples for class: 246
# >loaded 10 examples for class: 432
# >loaded 14 examples for class: 283
# >loaded 14 examples for class: 781
# >loaded 14 examples for class: 194
# >loaded 1 examples for class: 668
# >loaded 11 examples for class: 829
# >loaded 18 examples for class: 621
# >loaded 20 examples for class: 740
# >loaded 19 examples for class: 191
# >loaded 9 examples for class: 430
# >loaded 4 examples for class: 914
# >loaded 14 examples for class: 830
# >loaded 21 examples for class: 160
# >loaded 16 examples for class: 865
# >loaded 19 examples for class: 658
# >loaded 21 examples for class: 15
# >loaded 14 examples for class: 105
# >loaded 18 examples for class: 769
# >loaded 15 examples for class: 40
# >loaded 15 examples for class: 550
# >loaded 18 examples for class: 139
# >loaded 16 examples for class: 281
# >loaded 13 examples for class: 339
# >loaded 21 examples for class: 991
# >loaded 16 examples for class: 666
# >loaded 20 examples for class: 783
# >loaded 17 examples for class: 759
# >loaded 20 examples for class: 463
# >loaded 20 examples for class: 272
# >loaded 20 examples for class: 290
# >loaded 17 examples for class: 420
# >loaded 21 examples for class: 395
# >loaded 19 examples for class: 555
# >loaded 19 examples for class: 879
# >loaded 18 examples for class: 190
# >loaded 18 examples for class: 627
# >loaded 15 examples for class: 744
# >loaded 18 examples for class: 380
# >loaded 14 examples for class: 699
# >loaded 16 examples for class: 749
# >loaded 21 examples for class: 32
# >loaded 20 examples for class: 1
# >loaded 11 examples for class: 956
# >loaded 13 examples for class: 878
# >loaded 16 examples for class: 315
# >loaded 7 examples for class: 36
# >loaded 15 examples for class: 54
# >loaded 10 examples for class: 837
# >loaded 11 examples for class: 605
# >loaded 21 examples for class: 467
# >loaded 15 examples for class: 372
# >loaded 1 examples for class: 312
# >loaded 15 examples for class: 942
# >loaded 13 examples for class: 700
# >loaded 18 examples for class: 702
# >loaded 21 examples for class: 516
# >loaded 13 examples for class: 390
# >loaded 19 examples for class: 108
# >loaded 21 examples for class: 353
# >loaded 20 examples for class: 441
# >loaded 10 examples for class: 43
# >loaded 2 examples for class: 243
# >loaded 11 examples for class: 626
# >loaded 21 examples for class: 951
# >loaded 14 examples for class: 377
# >loaded 18 examples for class: 916
# >loaded 20 examples for class: 412
# >loaded 3 examples for class: 753
# >loaded 11 examples for class: 188
# >loaded 20 examples for class: 103
# >loaded 2 examples for class: 185
# >loaded 20 examples for class: 328
# >loaded 13 examples for class: 525
# >loaded 5 examples for class: 656
# >loaded 16 examples for class: 119
# >loaded 8 examples for class: 581
# >loaded 21 examples for class: 496
# >loaded 12 examples for class: 570
# >loaded 18 examples for class: 34
# >loaded 18 examples for class: 8
# >loaded 18 examples for class: 867
# >loaded 14 examples for class: 946
# >loaded 3 examples for class: 274
# >loaded 13 examples for class: 444
# >loaded 8 examples for class: 112
# >loaded 20 examples for class: 206
# >loaded 14 examples for class: 708
# >loaded 14 examples for class: 19
# >loaded 21 examples for class: 953
# >loaded 19 examples for class: 815
# >loaded 21 examples for class: 171
# >loaded 20 examples for class: 943
# >loaded 18 examples for class: 118
# >loaded 6 examples for class: 698
# >loaded 17 examples for class: 739
# >loaded 21 examples for class: 495
# >loaded 17 examples for class: 410
# >loaded 7 examples for class: 347
# >loaded 9 examples for class: 179
# >loaded 9 examples for class: 707
# >loaded 8 examples for class: 606
# >loaded 2 examples for class: 755
# >loaded 18 examples for class: 806
# >loaded 16 examples for class: 915
# >loaded 6 examples for class: 152
# >loaded 13 examples for class: 660
# >loaded 1 examples for class: 980
# >loaded 15 examples for class: 187
# >loaded 11 examples for class: 848
# >loaded 15 examples for class: 691
# >loaded 14 examples for class: 807
# >loaded 7 examples for class: 319
# >loaded 17 examples for class: 170
# >loaded 20 examples for class: 710
# >loaded 12 examples for class: 345
# >loaded 14 examples for class: 845
# >loaded 1 examples for class: 168
# >loaded 21 examples for class: 95
# >loaded 7 examples for class: 421
# >loaded 15 examples for class: 821
# >loaded 20 examples for class: 438
# >loaded 2 examples for class: 406
# >loaded 19 examples for class: 436
# >loaded 20 examples for class: 851
# >loaded 21 examples for class: 295
# >loaded 14 examples for class: 266
# >loaded 3 examples for class: 181
# >loaded 19 examples for class: 569
# >loaded 11 examples for class: 930
# >loaded 15 examples for class: 877
# >loaded 16 examples for class: 73
# >loaded 18 examples for class: 213
# >loaded 1 examples for class: 341
# >loaded 11 examples for class: 588
# >loaded 14 examples for class: 228
# >loaded 9 examples for class: 512
# >loaded 20 examples for class: 901
# >loaded 20 examples for class: 475
# >loaded 20 examples for class: 203
# >loaded 18 examples for class: 505
# >loaded 18 examples for class: 518
# >loaded 3 examples for class: 72
# >loaded 19 examples for class: 198
# >loaded 16 examples for class: 302
# >loaded 18 examples for class: 563
# >loaded 13 examples for class: 564
# >loaded 20 examples for class: 647
# >loaded 14 examples for class: 242
# >loaded 21 examples for class: 22
# >loaded 21 examples for class: 303
# >loaded 18 examples for class: 124
# >loaded 10 examples for class: 906
# >loaded 14 examples for class: 687
# >loaded 19 examples for class: 265
# >loaded 16 examples for class: 28
# >loaded 6 examples for class: 520
# >loaded 12 examples for class: 741
# >loaded 16 examples for class: 224
# >loaded 18 examples for class: 464
# >loaded 13 examples for class: 506
# >loaded 15 examples for class: 115
# >loaded 21 examples for class: 971
# >loaded 14 examples for class: 970
# >loaded 20 examples for class: 508
# >loaded 18 examples for class: 651
# >loaded 4 examples for class: 662
# >loaded 19 examples for class: 515
# >loaded 11 examples for class: 293
# >loaded 21 examples for class: 562
# >loaded 1 examples for class: 636
# >loaded 12 examples for class: 507
# >loaded 14 examples for class: 216
# >loaded 15 examples for class: 799
# >loaded 17 examples for class: 39
# >loaded 15 examples for class: 465
# >loaded 14 examples for class: 269
# >loaded 1 examples for class: 902
# >loaded 4 examples for class: 300
# >loaded 17 examples for class: 385
# >loaded 21 examples for class: 301
# >loaded 9 examples for class: 989
# >loaded 19 examples for class: 384
# >loaded 18 examples for class: 919
# >loaded 11 examples for class: 217
# >loaded 17 examples for class: 939
# >loaded 21 examples for class: 69
# >loaded 18 examples for class: 788
# >loaded 19 examples for class: 80
# >loaded 8 examples for class: 309
# >loaded 13 examples for class: 880
# >loaded 21 examples for class: 433
# >loaded 7 examples for class: 254
# >loaded 11 examples for class: 354
# >loaded 13 examples for class: 568
# >loaded 9 examples for class: 602
# >loaded 18 examples for class: 140
# >loaded 14 examples for class: 326
# >loaded 18 examples for class: 858
# >loaded 17 examples for class: 780
# >loaded 10 examples for class: 504
# >loaded 18 examples for class: 27
# >loaded 18 examples for class: 240
# >loaded 17 examples for class: 839
# >loaded 3 examples for class: 616
# >loaded 21 examples for class: 66
# >loaded 19 examples for class: 130
# >loaded 17 examples for class: 960
# >loaded 15 examples for class: 705
# >loaded 20 examples for class: 608
# >loaded 14 examples for class: 164
# >loaded 20 examples for class: 126
# >loaded 13 examples for class: 560
# >loaded 12 examples for class: 30
# >loaded 5 examples for class: 529
# >loaded 11 examples for class: 752
# >loaded 15 examples for class: 714
# >loaded 17 examples for class: 391
# >loaded 21 examples for class: 567
# >loaded 17 examples for class: 831
# >loaded 14 examples for class: 208
# >loaded 19 examples for class: 574
# >loaded 21 examples for class: 447
# >loaded 18 examples for class: 655
# >loaded 19 examples for class: 949
# >loaded 10 examples for class: 405
# >loaded 19 examples for class: 100
# >loaded 16 examples for class: 936
# >loaded 21 examples for class: 545
# >loaded 21 examples for class: 305
# >loaded 14 examples for class: 424
# >loaded 20 examples for class: 483
# >loaded 17 examples for class: 482
# >loaded 4 examples for class: 558
# >loaded 14 examples for class: 899
# >loaded 14 examples for class: 477
# >loaded 17 examples for class: 797
# >loaded 14 examples for class: 935
# >loaded 16 examples for class: 885
# >loaded 19 examples for class: 928
# >loaded 20 examples for class: 89
# >loaded 20 examples for class: 259
# >loaded 9 examples for class: 365
# >loaded 4 examples for class: 785
# >loaded 8 examples for class: 774
# >loaded 6 examples for class: 159
# >loaded 9 examples for class: 97
# >loaded 8 examples for class: 718
# >loaded 1 examples for class: 177
# >loaded 8 examples for class: 580
# >loaded 1 examples for class: 536
# >loaded 9 examples for class: 557
# >loaded 7 examples for class: 497
# >loaded 5 examples for class: 245
# >loaded 5 examples for class: 954
# >loaded 5 examples for class: 299
# >loaded 7 examples for class: 932
# >loaded 9 examples for class: 147
# >loaded 1 examples for class: 470
# >loaded 6 examples for class: 836
# >loaded 1 examples for class: 237
# >loaded 9 examples for class: 133
# >loaded 1 examples for class: 169
# >loaded 9 examples for class: 49
# >loaded 4 examples for class: 701
# >loaded 9 examples for class: 491
# >loaded 3 examples for class: 738
# >loaded 2 examples for class: 791
# >loaded 8 examples for class: 215
# >loaded 9 examples for class: 21
# >loaded 6 examples for class: 541
# >loaded 8 examples for class: 186
# >loaded 7 examples for class: 974
# >loaded 1 examples for class: 615
# >loaded 5 examples for class: 704
# >loaded 8 examples for class: 770
# >loaded 6 examples for class: 856
# >loaded 8 examples for class: 849
# >loaded 7 examples for class: 983
# >loaded 9 examples for class: 416
# >loaded 4 examples for class: 280
# >loaded 9 examples for class: 389
# >loaded 9 examples for class: 981
# >loaded 9 examples for class: 276
# >loaded 6 examples for class: 57
# >loaded 6 examples for class: 950
# >loaded 2 examples for class: 929
# >loaded 2 examples for class: 590
# >loaded 9 examples for class: 494
# >loaded 5 examples for class: 747
# >loaded 3 examples for class: 640
# >loaded 8 examples for class: 945
# >loaded 9 examples for class: 984
# >loaded 8 examples for class: 842
# >loaded 5 examples for class: 175
# >loaded 1 examples for class: 663
# >loaded 9 examples for class: 462
# >loaded 3 examples for class: 795
# >loaded 8 examples for class: 48
# >loaded 9 examples for class: 986
# >loaded 9 examples for class: 598
# >loaded 6 examples for class: 498
# >loaded 6 examples for class: 966
# >loaded 9 examples for class: 376
# >loaded 6 examples for class: 120
# >loaded 8 examples for class: 422
# >loaded 6 examples for class: 624
# >loaded 2 examples for class: 715
# >loaded 5 examples for class: 336
# >loaded 2 examples for class: 810
# >loaded 2 examples for class: 75
# >loaded 6 examples for class: 532
# >loaded 9 examples for class: 587
# >loaded 7 examples for class: 941
# >loaded 7 examples for class: 866
# >loaded 7 examples for class: 642
# >loaded 6 examples for class: 667
# >loaded 7 examples for class: 900
# >loaded 9 examples for class: 650
# >loaded 7 examples for class: 501
# >loaded 5 examples for class: 720
# >loaded 8 examples for class: 549
# >loaded 8 examples for class: 7
# >loaded 7 examples for class: 308
# >loaded 3 examples for class: 131
# >loaded 8 examples for class: 288
# >loaded 9 examples for class: 311
# >loaded 6 examples for class: 847
# >loaded 6 examples for class: 979
# >loaded 9 examples for class: 661
# >loaded 5 examples for class: 91
# >loaded 7 examples for class: 33
# >loaded 8 examples for class: 825
# >loaded 9 examples for class: 539
# >loaded 9 examples for class: 458
# >loaded 2 examples for class: 360
# >loaded 7 examples for class: 451
# >loaded 8 examples for class: 415
# >loaded 9 examples for class: 784
# >loaded 6 examples for class: 10
# >loaded 2 examples for class: 832
# >loaded 6 examples for class: 802
# >loaded 1 examples for class: 456
# >loaded 1 examples for class: 725
# >loaded 8 examples for class: 896
# >loaded 9 examples for class: 907
# >loaded 8 examples for class: 158
# >loaded 8 examples for class: 3
# >loaded 2 examples for class: 882
# >loaded 8 examples for class: 730
# >loaded 7 examples for class: 746
# >loaded 8 examples for class: 117
# >loaded 6 examples for class: 511
# >loaded 5 examples for class: 435
# >loaded 7 examples for class: 407
# >loaded 9 examples for class: 768
# >loaded 1 examples for class: 912
# >loaded 6 examples for class: 196
# >loaded 8 examples for class: 689
# >loaded 8 examples for class: 86
# >loaded 2 examples for class: 982
# >loaded 7 examples for class: 450
# >loaded 9 examples for class: 775
# >loaded 9 examples for class: 145
# >loaded 9 examples for class: 992
# >loaded 9 examples for class: 374
# >loaded 9 examples for class: 180
# >loaded 4 examples for class: 554
# >loaded 3 examples for class: 144
# >loaded 5 examples for class: 221
# >loaded 9 examples for class: 116
# >loaded 9 examples for class: 764
# >loaded 9 examples for class: 442
# >loaded 9 examples for class: 987
# >loaded 9 examples for class: 359
# >loaded 9 examples for class: 460
# >loaded 6 examples for class: 713
# >loaded 9 examples for class: 313
# >loaded 7 examples for class: 544
# >loaded 9 examples for class: 480
# >loaded 6 examples for class: 102
# >loaded 9 examples for class: 940
# >loaded 7 examples for class: 184
# >loaded 9 examples for class: 273
# >loaded 9 examples for class: 247
# >loaded 9 examples for class: 234
# >loaded 9 examples for class: 263
# >loaded 1 examples for class: 638
# >loaded 9 examples for class: 669
# >loaded 6 examples for class: 271
# >loaded 3 examples for class: 488
# >loaded 7 examples for class: 453
# >loaded 9 examples for class: 382
# >loaded 7 examples for class: 648
# >loaded 8 examples for class: 261
# >loaded 3 examples for class: 635
# >loaded 2 examples for class: 751
# >loaded 8 examples for class: 279
# >loaded 9 examples for class: 250
# >loaded 9 examples for class: 320
# >loaded 3 examples for class: 639
# >loaded 9 examples for class: 706
# >loaded 8 examples for class: 874
# >loaded 8 examples for class: 172
# >loaded 9 examples for class: 96
# >loaded 6 examples for class: 109
# >loaded 9 examples for class: 222
# >loaded 6 examples for class: 884
# >loaded 6 examples for class: 324
# >loaded 6 examples for class: 62
# >loaded 9 examples for class: 79
# >loaded 6 examples for class: 379
# >loaded 8 examples for class: 489
# >loaded 9 examples for class: 335
# >loaded 9 examples for class: 23
# >loaded 9 examples for class: 322
# >loaded 4 examples for class: 681
# >loaded 6 examples for class: 325
# >loaded 9 examples for class: 256
# >loaded 6 examples for class: 685
# >loaded 9 examples for class: 871
# >loaded 7 examples for class: 716
# >loaded 7 examples for class: 579
# >loaded 6 examples for class: 233
# >loaded 8 examples for class: 156
# >loaded 9 examples for class: 798
# >loaded 8 examples for class: 163
# >loaded 7 examples for class: 743
# >loaded 9 examples for class: 599
# >loaded 9 examples for class: 59
# >loaded 5 examples for class: 314
# >loaded 9 examples for class: 468
# >loaded 6 examples for class: 921
# >loaded 8 examples for class: 167
# >loaded 8 examples for class: 898
# >loaded 6 examples for class: 789
# >loaded 8 examples for class: 500
# >loaded 1 examples for class: 111
# >loaded 7 examples for class: 53
# >loaded 1 examples for class: 478
# >loaded 8 examples for class: 530
# >loaded 1 examples for class: 223
# >loaded 3 examples for class: 2
# >loaded 6 examples for class: 399
# >loaded 6 examples for class: 493
# >loaded 9 examples for class: 731
# >loaded 7 examples for class: 428
# >loaded 9 examples for class: 403
# >loaded 7 examples for class: 786
# >loaded 5 examples for class: 682
# >loaded 7 examples for class: 452
# >loaded 9 examples for class: 47
# >loaded 7 examples for class: 88
# >loaded 8 examples for class: 596
# >loaded 9 examples for class: 343
# >loaded 8 examples for class: 137
# >loaded 8 examples for class: 644
# >loaded 7 examples for class: 509
# >loaded 9 examples for class: 439
# >loaded 2 examples for class: 712
# >loaded 9 examples for class: 404
# >loaded 5 examples for class: 71
# >loaded 1 examples for class: 630
# >loaded 8 examples for class: 58
# >loaded 3 examples for class: 908
# >loaded 9 examples for class: 174
# >loaded 9 examples for class: 674
# >loaded 6 examples for class: 285
# >loaded 9 examples for class: 955
# >loaded 6 examples for class: 732
# >loaded 4 examples for class: 540
# >loaded 6 examples for class: 225
# >loaded 9 examples for class: 782
# >loaded 9 examples for class: 370
# >loaded 8 examples for class: 548
# >loaded 9 examples for class: 413
# >loaded 9 examples for class: 676
# >loaded 8 examples for class: 622
# >loaded 6 examples for class: 792
# >loaded 6 examples for class: 591
# >loaded 6 examples for class: 933
# >loaded 7 examples for class: 229
# >loaded 7 examples for class: 927
# >loaded 6 examples for class: 938
# >loaded 6 examples for class: 362
# >loaded 8 examples for class: 195
# >loaded 9 examples for class: 363
# >loaded 9 examples for class: 14
# >loaded 9 examples for class: 251
# >loaded 6 examples for class: 29
# >loaded 6 examples for class: 808
# >loaded 1 examples for class: 566
# >loaded 2 examples for class: 267
# >loaded 9 examples for class: 55
# >loaded 3 examples for class: 812
# >loaded 9 examples for class: 459
# >loaded 9 examples for class: 239
# >loaded 9 examples for class: 113
# >loaded 7 examples for class: 771
# >loaded 4 examples for class: 695
# >loaded 5 examples for class: 757
# >loaded 8 examples for class: 106
# >loaded 7 examples for class: 296
# >loaded 9 examples for class: 521
# >loaded 7 examples for class: 963
# >loaded 6 examples for class: 90
# >loaded 5 examples for class: 816
# >loaded 7 examples for class: 684
# >loaded 8 examples for class: 895
# >loaded 9 examples for class: 31
# >loaded 9 examples for class: 665
# >loaded 9 examples for class: 446
# >loaded 9 examples for class: 818
# >loaded 8 examples for class: 528
# >loaded 5 examples for class: 178
# >loaded 6 examples for class: 728
# >loaded 7 examples for class: 888
# >loaded 7 examples for class: 721
# >loaded 9 examples for class: 278
# >loaded 5 examples for class: 897
# >loaded 8 examples for class: 364
# >loaded 9 examples for class: 199
# >loaded 6 examples for class: 297
# >loaded 9 examples for class: 394
# >loaded 7 examples for class: 455
# >loaded 4 examples for class: 127
# >loaded 9 examples for class: 492
# >loaded 3 examples for class: 838
# >loaded 1 examples for class: 513
# >loaded 7 examples for class: 162
# >loaded 9 examples for class: 779
# >loaded 7 examples for class: 41
# >loaded 9 examples for class: 859
# >loaded 9 examples for class: 524
# >loaded 9 examples for class: 82
# >loaded 9 examples for class: 776
# >loaded 9 examples for class: 843
# >loaded 1 examples for class: 813
# >loaded 7 examples for class: 854
# >loaded 7 examples for class: 13
# >loaded 7 examples for class: 887
# >loaded 7 examples for class: 926
# >loaded 6 examples for class: 378
# >loaded 9 examples for class: 787
# >loaded 8 examples for class: 218
# >loaded 1 examples for class: 346
# >loaded 4 examples for class: 398
# >loaded 1 examples for class: 356
# >loaded 3 examples for class: 298
# >loaded 4 examples for class: 340
# >loaded 6 examples for class: 51
# >loaded 2 examples for class: 219
# >loaded 6 examples for class: 864
# >loaded 6 examples for class: 611
# >loaded 7 examples for class: 6
# >loaded 8 examples for class: 561
# >loaded 6 examples for class: 811
# >loaded 9 examples for class: 978
# >loaded 9 examples for class: 471
# >loaded 8 examples for class: 834
# >loaded 1 examples for class: 469
# >loaded 9 examples for class: 527
# >loaded 6 examples for class: 680
# >loaded 7 examples for class: 672
# >loaded 9 examples for class: 461
# >loaded 1 examples for class: 526
# >loaded 9 examples for class: 289
# >loaded 8 examples for class: 814
# >loaded 7 examples for class: 344
# >loaded 6 examples for class: 454
# >loaded 4 examples for class: 42
# >loaded 2 examples for class: 200
# >loaded 9 examples for class: 87
# >loaded 7 examples for class: 824
# >loaded 9 examples for class: 735
# >loaded 9 examples for class: 226
# >loaded 9 examples for class: 205
# >loaded 6 examples for class: 841
# >loaded 5 examples for class: 136
# >loaded 6 examples for class: 342
# >loaded 7 examples for class: 93
# >loaded 9 examples for class: 107
# >loaded 9 examples for class: 425
# >loaded 8 examples for class: 652
# >loaded 7 examples for class: 84
# >loaded 6 examples for class: 629
# >loaded 7 examples for class: 994
# >loaded 1 examples for class: 641
# >loaded 8 examples for class: 646
# >loaded 4 examples for class: 571
# >loaded 7 examples for class: 270
# >loaded 9 examples for class: 894
# >loaded 9 examples for class: 373
# >loaded 9 examples for class: 318
# >loaded 9 examples for class: 975
# >loaded 1 examples for class: 76
# >loaded 3 examples for class: 754
# >loaded 9 examples for class: 631
# >loaded 9 examples for class: 375
# >loaded 6 examples for class: 310
# >loaded 6 examples for class: 275
# >loaded 6 examples for class: 793
# >loaded 6 examples for class: 585
# >loaded 9 examples for class: 542
# >loaded 9 examples for class: 155
# >loaded 7 examples for class: 400
# >loaded 8 examples for class: 881
# >loaded 9 examples for class: 801
# >loaded 5 examples for class: 474
# >loaded 8 examples for class: 148
# >loaded 8 examples for class: 357
# >loaded 2 examples for class: 9
# >loaded 5 examples for class: 484
# >loaded 7 examples for class: 645
# >loaded 6 examples for class: 805
# >loaded 7 examples for class: 860
# >loaded 3 examples for class: 683
# >loaded 7 examples for class: 287
# >loaded 9 examples for class: 961
# >loaded 7 examples for class: 913
# >loaded 9 examples for class: 220
# >loaded 7 examples for class: 366
# >loaded 9 examples for class: 361
# >loaded 6 examples for class: 625
# >loaded 9 examples for class: 388
# >loaded 9 examples for class: 835
# >loaded 9 examples for class: 620
# >loaded 1 examples for class: 920
# >loaded 9 examples for class: 122
# >loaded 9 examples for class: 565
# >loaded 9 examples for class: 138
# >loaded 1 examples for class: 307
# >loaded 9 examples for class: 393
# >loaded 7 examples for class: 437
# ...
# >loaded 9 examples for class: 592
# >loaded 6 examples for class: 637
# >loaded 5 examples for class: 690
# >loaded 6 examples for class: 925
# >loaded 3 examples for class: 16
# >loaded 6 examples for class: 227
# >loaded 9 examples for class: 632
# >loaded 9 examples for class: 207
# >loaded 6 examples for class: 922
# >loaded 3 examples for class: 737
# >loaded 9 examples for class: 649
# >loaded 6 examples for class: 910
# >loaded 9 examples for class: 61
# >loaded 7 examples for class: 514
# >loaded 6 examples for class: 24
# >loaded 4 examples for class: 429
# >loaded 8 examples for class: 264
# >loaded 3 examples for class: 189
# >loaded 8 examples for class: 110
# >loaded 7 examples for class: 63
# >loaded 9 examples for class: 457
# >loaded 8 examples for class: 724
# >loaded 9 examples for class: 68
# >loaded 9 examples for class: 387
# >loaded 7 examples for class: 166
# >loaded 3 examples for class: 503
# >loaded 6 examples for class: 551
# >loaded 6 examples for class: 833
# >loaded 3 examples for class: 154
# >loaded 9 examples for class: 958
# >loaded 9 examples for class: 417
# >loaded 6 examples for class: 765
# >loaded 6 examples for class: 316
# >loaded 9 examples for class: 292
# >loaded 7 examples for class: 426
# >loaded 6 examples for class: 883
# >loaded 7 examples for class: 99
# >loaded 6 examples for class: 333
# >loaded 8 examples for class: 756
# >loaded 8 examples for class: 869
# >loaded 7 examples for class: 4
# >loaded 9 examples for class: 449
# >loaded 7 examples for class: 575
# >loaded 2 examples for class: 44
# >loaded 8 examples for class: 98
# >loaded 3 examples for class: 11
# >loaded 9 examples for class: 547
# >loaded 9 examples for class: 889
# >loaded 9 examples for class: 257
# >loaded 5 examples for class: 183
# >loaded 9 examples for class: 204
# >loaded 8 examples for class: 157
# >loaded 9 examples for class: 306
# >loaded 5 examples for class: 556
# >loaded 6 examples for class: 369
# >loaded 9 examples for class: 578
# >loaded 3 examples for class: 762
# >loaded 9 examples for class: 101
# >loaded 9 examples for class: 973
# >loaded 7 examples for class: 623
# >loaded 8 examples for class: 931
# >loaded 6 examples for class: 252
# >loaded 9 examples for class: 349
# >loaded 6 examples for class: 502
# >loaded 7 examples for class: 45
# >loaded 9 examples for class: 604
# >loaded 4 examples for class: 202
# >loaded 3 examples for class: 236
# >loaded 4 examples for class: 490
# >loaded 8 examples for class: 125
# >loaded 5 examples for class: 653
# >loaded 9 examples for class: 985
# >loaded 8 examples for class: 804
# >loaded 3 examples for class: 962
# >loaded 4 examples for class: 402
# >loaded 4 examples for class: 827
# >loaded 3 examples for class: 321
# >loaded 8 examples for class: 165
# >loaded 8 examples for class: 330
# >loaded 4 examples for class: 893
# >loaded 6 examples for class: 210
# >loaded 6 examples for class: 748
# >loaded 9 examples for class: 977
# >loaded 8 examples for class: 338
# >loaded 9 examples for class: 678
# >loaded 6 examples for class: 434
# >loaded 7 examples for class: 610
# >loaded 9 examples for class: 758
# >loaded 6 examples for class: 609
# >loaded 9 examples for class: 423
# >loaded 9 examples for class: 143
# >loaded 8 examples for class: 52
# >loaded 9 examples for class: 861
# >loaded 6 examples for class: 968
# >loaded 7 examples for class: 418
# >loaded 9 examples for class: 657
# >loaded 9 examples for class: 553
# >loaded 6 examples for class: 822
# >loaded 9 examples for class: 863
# >loaded 9 examples for class: 612
# >loaded 2 examples for class: 995
# >loaded 9 examples for class: 727
# >loaded 3 examples for class: 613
# >loaded 7 examples for class: 633
# >loaded 3 examples for class: 703
# >loaded 6 examples for class: 20
# >loaded 8 examples for class: 767
# >loaded 6 examples for class: 990
# >loaded 8 examples for class: 643
# >loaded 9 examples for class: 671
# >loaded 1 examples for class: 26
# >loaded 9 examples for class: 800
# >loaded 9 examples for class: 614
# >loaded 6 examples for class: 50
# >loaded 3 examples for class: 840
# >loaded 9 examples for class: 909
# >loaded 7 examples for class: 212
# >loaded 9 examples for class: 719
# >loaded 7 examples for class: 773
# >loaded 9 examples for class: 25
# >loaded 4 examples for class: 193
# >loaded 1 examples for class: 763
# >loaded 3 examples for class: 37
# >loaded 5 examples for class: 35
# >loaded 9 examples for class: 742
# >loaded 5 examples for class: 337
# >loaded 4 examples for class: 726
# >loaded 9 examples for class: 675
# >loaded 3 examples for class: 634
# >loaded 9 examples for class: 485
# >loaded 8 examples for class: 794
# >loaded 9 examples for class: 600
# >loaded 6 examples for class: 948
# >loaded 8 examples for class: 427
# >loaded 5 examples for class: 820
# >loaded 5 examples for class: 238
# >loaded 3 examples for class: 537
# >loaded 9 examples for class: 481
# >loaded 2 examples for class: 329
# >loaded 2 examples for class: 853
# >loaded 9 examples for class: 523
# >loaded 6 examples for class: 367
# >loaded 5 examples for class: 231
# >loaded 8 examples for class: 952
# >loaded 9 examples for class: 947
# >loaded 7 examples for class: 535
# >loaded 9 examples for class: 371
# >loaded 9 examples for class: 409
# >loaded 7 examples for class: 232
# >loaded 7 examples for class: 734
# >loaded 7 examples for class: 959
# >loaded 1 examples for class: 673
# >loaded 1 examples for class: 74
# >loaded 5 examples for class: 538
# >loaded 9 examples for class: 291
# >loaded 9 examples for class: 78
# >loaded 6 examples for class: 396
# >loaded 9 examples for class: 677
# >loaded 8 examples for class: 331
# >loaded 1 examples for class: 522
# >loaded 9 examples for class: 284
# >loaded 5 examples for class: 241
# >loaded 9 examples for class: 999
# >loaded 6 examples for class: 559
# >loaded 7 examples for class: 586
# >loaded 5 examples for class: 905
# >loaded 7 examples for class: 473
# >loaded 9 examples for class: 64
# >loaded 1 examples for class: 244
# >loaded 3 examples for class: 729
# >loaded 6 examples for class: 294
# >loaded 3 examples for class: 891
# >loaded 5 examples for class: 182
# >loaded 9 examples for class: 944
# >loaded 9 examples for class: 351
# >loaded 3 examples for class: 709
# >loaded 7 examples for class: 141
# >loaded 7 examples for class: 817
# >loaded 7 examples for class: 401
# >loaded 8 examples for class: 876
# >loaded 9 examples for class: 81
# >loaded 2 examples for class: 722
# >loaded 2 examples for class: 249
# >loaded 9 examples for class: 487
# >loaded 8 examples for class: 173
# >loaded 7 examples for class: 408
# >loaded 4 examples for class: 618
# >loaded 4 examples for class: 201
# >loaded 9 examples for class: 594
# >loaded 2 examples for class: 996
# >loaded 9 examples for class: 445
# >loaded 8 examples for class: 750
# >loaded 4 examples for class: 664
# >loaded 3 examples for class: 472
# >loaded 3 examples for class: 998
# >loaded 9 examples for class: 576
# >loaded 7 examples for class: 852
# >loaded 7 examples for class: 875
# >loaded 6 examples for class: 211
# >loaded 6 examples for class: 778
# >loaded 9 examples for class: 17
# >loaded 9 examples for class: 248
# >loaded 3 examples for class: 479
# >loaded 9 examples for class: 121
# >loaded 9 examples for class: 386
# >loaded 1 examples for class: 917
# >loaded 9 examples for class: 192
# >loaded 6 examples for class: 911
# >loaded 9 examples for class: 844
# >loaded 6 examples for class: 60
# >loaded 7 examples for class: 855
# >loaded 7 examples for class: 92
# >loaded 1 examples for class: 582
# >loaded 8 examples for class: 583
# >loaded 6 examples for class: 969
# >loaded 7 examples for class: 619
# >loaded 9 examples for class: 534
# >loaded 8 examples for class: 694
# >loaded 6 examples for class: 332
# >loaded 3 examples for class: 431
# >loaded 8 examples for class: 693
# >loaded 7 examples for class: 957
# >loaded 6 examples for class: 803
# >loaded 9 examples for class: 733
# >loaded 9 examples for class: 997
# >loaded 6 examples for class: 83
# >loaded 9 examples for class: 466
# >loaded 9 examples for class: 772
# >loaded 9 examples for class: 918
# >loaded 2 examples for class: 149
# >loaded 1 examples for class: 246
# >loaded 5 examples for class: 432
# >loaded 6 examples for class: 283
# >loaded 6 examples for class: 781
# >loaded 7 examples for class: 194
# >loaded 1 examples for class: 668
# >loaded 5 examples for class: 829
# >loaded 8 examples for class: 621
# >loaded 9 examples for class: 740
# >loaded 9 examples for class: 191
# >loaded 5 examples for class: 430
# >loaded 2 examples for class: 914
# >loaded 6 examples for class: 830
# >loaded 9 examples for class: 160
# >loaded 7 examples for class: 865
# >loaded 9 examples for class: 658
# >loaded 9 examples for class: 15
# >loaded 7 examples for class: 105
# >loaded 9 examples for class: 769
# >loaded 7 examples for class: 40
# >loaded 7 examples for class: 550
# >loaded 8 examples for class: 139
# >loaded 7 examples for class: 281
# >loaded 6 examples for class: 339
# >loaded 9 examples for class: 991
# >loaded 8 examples for class: 666
# >loaded 9 examples for class: 783
# >loaded 8 examples for class: 759
# >loaded 9 examples for class: 463
# >loaded 9 examples for class: 272
# >loaded 9 examples for class: 290
# >loaded 8 examples for class: 420
# >loaded 9 examples for class: 395
# >loaded 9 examples for class: 555
# >loaded 9 examples for class: 879
# >loaded 9 examples for class: 190
# >loaded 8 examples for class: 627
# >loaded 8 examples for class: 744
# >loaded 9 examples for class: 380
# >loaded 7 examples for class: 699
# >loaded 8 examples for class: 749
# >loaded 9 examples for class: 32
# >loaded 9 examples for class: 1
# >loaded 6 examples for class: 956
# >loaded 6 examples for class: 878
# >loaded 7 examples for class: 315
# >loaded 4 examples for class: 36
# >loaded 7 examples for class: 54
# >loaded 5 examples for class: 837
# >loaded 6 examples for class: 605
# >loaded 9 examples for class: 467
# >loaded 7 examples for class: 372
# >loaded 1 examples for class: 312
# >loaded 7 examples for class: 942
# >loaded 6 examples for class: 700
# >loaded 9 examples for class: 702
# >loaded 9 examples for class: 516
# >loaded 6 examples for class: 390
# >loaded 9 examples for class: 108
# >loaded 9 examples for class: 353
# >loaded 9 examples for class: 441
# >loaded 5 examples for class: 43
# >loaded 1 examples for class: 243
# >loaded 5 examples for class: 626
# >loaded 9 examples for class: 951
# >loaded 7 examples for class: 377
# >loaded 9 examples for class: 916
# >loaded 9 examples for class: 412
# >loaded 2 examples for class: 753
# >loaded 6 examples for class: 188
# >loaded 9 examples for class: 103
# >loaded 1 examples for class: 185
# >loaded 9 examples for class: 328
# >loaded 6 examples for class: 525
# >loaded 3 examples for class: 656
# >loaded 8 examples for class: 119
# >loaded 4 examples for class: 581
# >loaded 9 examples for class: 496
# >loaded 6 examples for class: 570
# >loaded 8 examples for class: 34
# >loaded 8 examples for class: 8
# >loaded 9 examples for class: 867
# >loaded 6 examples for class: 946
# >loaded 2 examples for class: 274
# >loaded 6 examples for class: 444
# >loaded 4 examples for class: 112
# >loaded 9 examples for class: 206
# >loaded 7 examples for class: 708
# >loaded 6 examples for class: 19
# >loaded 9 examples for class: 953
# >loaded 9 examples for class: 815
# >loaded 9 examples for class: 171
# >loaded 9 examples for class: 943
# >loaded 9 examples for class: 118
# >loaded 3 examples for class: 698
# >loaded 8 examples for class: 739
# >loaded 9 examples for class: 495
# >loaded 8 examples for class: 410
# >loaded 3 examples for class: 347
# >loaded 5 examples for class: 179
# >loaded 5 examples for class: 707
# >loaded 4 examples for class: 606
# >loaded 2 examples for class: 755
# >loaded 9 examples for class: 806
# >loaded 8 examples for class: 915
# >loaded 3 examples for class: 152
# >loaded 6 examples for class: 660
# >loaded 1 examples for class: 980
# >loaded 7 examples for class: 187
# >loaded 5 examples for class: 848
# >loaded 7 examples for class: 691
# >loaded 7 examples for class: 807
# >loaded 3 examples for class: 319
# >loaded 8 examples for class: 170
# >loaded 9 examples for class: 710
# >loaded 6 examples for class: 345
# >loaded 7 examples for class: 845
# >loaded 1 examples for class: 168
# >loaded 9 examples for class: 95
# >loaded 4 examples for class: 421
# >loaded 7 examples for class: 821
# >loaded 9 examples for class: 438
# >loaded 2 examples for class: 406
# >loaded 9 examples for class: 436
# >loaded 9 examples for class: 851
# >loaded 9 examples for class: 295
# >loaded 6 examples for class: 266
# >loaded 2 examples for class: 181
# >loaded 9 examples for class: 569
# >loaded 5 examples for class: 930
# >loaded 7 examples for class: 877
# >loaded 8 examples for class: 73
# >loaded 8 examples for class: 213
# >loaded 1 examples for class: 341
# >loaded 6 examples for class: 588
# >loaded 7 examples for class: 228
# >loaded 4 examples for class: 512
# >loaded 9 examples for class: 901
# >loaded 9 examples for class: 475
# >loaded 9 examples for class: 203
# >loaded 9 examples for class: 505
# >loaded 9 examples for class: 518
# >loaded 2 examples for class: 72
# >loaded 9 examples for class: 198
# >loaded 7 examples for class: 302
# >loaded 8 examples for class: 563
# >loaded 6 examples for class: 564
# >loaded 9 examples for class: 647
# >loaded 6 examples for class: 242
# >loaded 9 examples for class: 22
# >loaded 9 examples for class: 303
# >loaded 9 examples for class: 124
# >loaded 5 examples for class: 906
# >loaded 6 examples for class: 687
# >loaded 9 examples for class: 265
# >loaded 7 examples for class: 28
# >loaded 3 examples for class: 520
# >loaded 6 examples for class: 741
# >loaded 7 examples for class: 224
# >loaded 9 examples for class: 464
# >loaded 6 examples for class: 506
# >loaded 7 examples for class: 115
# >loaded 9 examples for class: 971
# >loaded 6 examples for class: 970
# >loaded 9 examples for class: 508
# >loaded 9 examples for class: 651
# >loaded 3 examples for class: 662
# >loaded 9 examples for class: 515
# >loaded 5 examples for class: 293
# >loaded 9 examples for class: 562
# >loaded 1 examples for class: 636
# >loaded 6 examples for class: 507
# >loaded 7 examples for class: 216
# >loaded 7 examples for class: 799
# >loaded 8 examples for class: 39
# >loaded 7 examples for class: 465
# >loaded 7 examples for class: 269
# >loaded 1 examples for class: 902
# >loaded 2 examples for class: 300
# >loaded 8 examples for class: 385
# >loaded 9 examples for class: 301
# >loaded 4 examples for class: 989
# >loaded 9 examples for class: 384
# >loaded 9 examples for class: 919
# >loaded 6 examples for class: 217
# >loaded 8 examples for class: 939
# >loaded 9 examples for class: 69
# >loaded 9 examples for class: 788
# >loaded 9 examples for class: 80
# >loaded 4 examples for class: 309
# >loaded 6 examples for class: 880
# >loaded 9 examples for class: 433
# >loaded 3 examples for class: 254
# >loaded 6 examples for class: 354
# >loaded 6 examples for class: 568
# >loaded 5 examples for class: 602
# >loaded 9 examples for class: 140
# >loaded 6 examples for class: 326
# >loaded 8 examples for class: 858
# >loaded 8 examples for class: 780
# >loaded 5 examples for class: 504
# >loaded 8 examples for class: 27
# >loaded 8 examples for class: 240
# >loaded 8 examples for class: 839
# >loaded 2 examples for class: 616
# >loaded 9 examples for class: 66
# >loaded 9 examples for class: 130
# >loaded 8 examples for class: 960
# >loaded 7 examples for class: 705
# >loaded 9 examples for class: 608
# >loaded 7 examples for class: 164
# >loaded 9 examples for class: 126
# >loaded 6 examples for class: 560
# >loaded 6 examples for class: 30
# >loaded 3 examples for class: 529
# >loaded 6 examples for class: 752
# >loaded 7 examples for class: 714
# >loaded 8 examples for class: 391
# >loaded 9 examples for class: 567
# >loaded 8 examples for class: 831
# >loaded 6 examples for class: 208
# >loaded 9 examples for class: 574
# >loaded 9 examples for class: 447
# >loaded 8 examples for class: 655
# >loaded 9 examples for class: 949
# >loaded 5 examples for class: 405
# >loaded 9 examples for class: 100
# >loaded 7 examples for class: 936
# >loaded 9 examples for class: 545
# >loaded 9 examples for class: 305
# >loaded 7 examples for class: 424
# >loaded 9 examples for class: 483
# >loaded 8 examples for class: 482
# >loaded 2 examples for class: 558
# >loaded 6 examples for class: 899
# >loaded 6 examples for class: 477
# >loaded 8 examples for class: 797
# >loaded 6 examples for class: 935
# >loaded 8 examples for class: 885
# >loaded 9 examples for class: 928
# >loaded 9 examples for class: 89
# >loaded 9 examples for class: 259

# %%
print(len(np.unique(testy)))
print(len(np.unique(trainy)))
# Out:
# 1000
# 1000

# %%
# This file can be pretty large since it is essentially a numpy array with
# simple compression.  May or may not need 
savez_compressed(dataset + '/faces.npz', trainX, trainy, testX, testy)

# %% [markdown]
# ## Create Face Embeddings

# %%
# load the face dataset
data = load(dataset + 'faces.npz')
trainX, trainy, testX, testy = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']
print('Loaded: ', trainX.shape, trainy.shape, testX.shape, testy.shape)
# load the facenet model
model_enc = load_model('facenet_keras.h5')
print('Loaded Model')
# Out:
# Loaded:  (14406, 160, 160, 3) (14406,) (6722, 160, 160, 3) (6722,)
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# Loaded Model

# %%
# get the face embedding for one face
def get_embedding(model, samples):
    # scale pixel values
    samples = samples.astype('float32')
    
    #print(samples.shape)
    # standardize pixel values across channels (global)
    
    #mean, std = samples.mean(), samples.std()
    #samples = (samples - mean)/std
    
    #print(std.shape)
    #face_pixels = (face_pixels - mean) / std
    # transform face into one sample
    #samples = expand_dims(face_pixels, axis=0)
    #print(samples.shape)
    # make prediction to get embedding
    
    yhat = model.predict(samples)
    return yhat

# %%
# Another preprocessing step, we do this here instead so that
# faces.npz contains the original image and we can display the original image if needed

# Normalize data using mean and std from trainX
mean = trainX.mean()
std = trainX.std()

print("mean:", mean)
print("std: ", std)

trainX = (trainX - mean) / std
testX = (testX - mean) / std
# Out:
# mean: 127.41816755496842
# std:  63.643689073805

# %%
# convert each face in the train set to an embedding
trainX = get_embedding(model_enc, trainX)
testX = get_embedding(model_enc, testX)

savez_compressed(dataset + 'embeddings.npz', trainX, trainy, testX, testy)

# %%
trainX.shape
# Out:
# (14406, 128)

# %%
testX.shape
# Out:
# (6722, 128)

# %% [markdown]
# ## Training Softmax Classifier
#
# This step reads in the embeddings and labels for the training set and trains a softmax classifier to recognize the identity of the person given the 128-dimensional embedding vector.

# %%
data = load(dataset + '/embeddings.npz')
trainX, trainy, testX, testy = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']
trainy = trainy.astype(np.uint32)
testy = testy.astype(np.uint32)

#out_encoder = LabelEncoder()
#out_encoder.fit(trainy)
#trainy = out_encoder.transform(trainy)
#testy = out_encoder.transform(testy)

# %%
# The directories we have are labeled from 1-1000
# subtract one so that 
trainy = trainy - 1
testy = testy - 1

# %%
num_classes = len(np.unique(trainy))
num_classes
# Out:
# 1000

# %%
trainy = to_categorical(trainy)
testy = to_categorical(testy)

# %%
trainy.shape
# Out:
# (14406, 1000)

# %%
# Model for softmax classification
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow import keras
from tensorflow.keras import Input
from tensorflow.keras import layers

model = Sequential()
model.add(Input(shape=(128,)))
#model.add(layers.Dense(250, kernel_regularizer='l2'))
#model.add(layers.Dropout(rate=0.5))
model.add(layers.Dense(num_classes, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1000)              129000
# =================================================================
# Total params: 129,000
# Trainable params: 129,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set optimizer, loss function, and metrics
opt = optimizers.Adam(lr=0.001)
model.compile(loss='categorical_crossentropy', optimizer = opt, metrics = ['acc'])

# %%
# Train!
history = model.fit(trainX, trainy, validation_data=(testX, testy), batch_size=64, epochs=15)
# Out:
# Train on 14406 samples, validate on 6722 samples
# Epoch 1/15
# 14406/14406 [==============================] - 1s 61us/sample - loss: 5.3321 - acc: 0.4018 - val_loss: 3.6376 - val_acc: 0.7920
# Epoch 2/15
# 14406/14406 [==============================] - 1s 47us/sample - loss: 2.4824 - acc: 0.8597 - val_loss: 1.7176 - val_acc: 0.8841
# Epoch 3/15
# 14406/14406 [==============================] - 1s 48us/sample - loss: 1.1621 - acc: 0.9207 - val_loss: 1.0345 - val_acc: 0.9130
# Epoch 4/15
# 14406/14406 [==============================] - 1s 46us/sample - loss: 0.6965 - acc: 0.9421 - val_loss: 0.7699 - val_acc: 0.9255
# Epoch 5/15
# 14406/14406 [==============================] - 1s 47us/sample - loss: 0.4955 - acc: 0.9539 - val_loss: 0.6447 - val_acc: 0.9277
# Epoch 6/15
# 14406/14406 [==============================] - 1s 47us/sample - loss: 0.3858 - acc: 0.9611 - val_loss: 0.5745 - val_acc: 0.9322
# Epoch 7/15
# 14406/14406 [==============================] - 1s 48us/sample - loss: 0.3159 - acc: 0.9666 - val_loss: 0.5308 - val_acc: 0.9320
# Epoch 8/15
# 14406/14406 [==============================] - 1s 44us/sample - loss: 0.2669 - acc: 0.9708 - val_loss: 0.5028 - val_acc: 0.9313
# Epoch 9/15
# 14406/14406 [==============================] - 1s 46us/sample - loss: 0.2303 - acc: 0.9751 - val_loss: 0.4847 - val_acc: 0.9320
# Epoch 10/15
# 14406/14406 [==============================] - 1s 51us/sample - loss: 0.2012 - acc: 0.9779 - val_loss: 0.4718 - val_acc: 0.9314
# Epoch 11/15
# 14406/14406 [==============================] - 1s 47us/sample - loss: 0.1784 - acc: 0.9793 - val_loss: 0.4618 - val_acc: 0.9307
# Epoch 12/15
# 14406/14406 [==============================] - 1s 45us/sample - loss: 0.1590 - acc: 0.9816 - val_loss: 0.4558 - val_acc: 0.9296
# Epoch 13/15
# 14406/14406 [==============================] - 1s 45us/sample - loss: 0.1430 - acc: 0.9826 - val_loss: 0.4513 - val_acc: 0.9296
# Epoch 14/15
# 14406/14406 [==============================] - 1s 46us/sample - loss: 0.1293 - acc: 0.9838 - val_loss: 0.4487 - val_acc: 0.9274
# Epoch 15/15
# 14406/14406 [==============================] - 1s 47us/sample - loss: 0.1178 - acc: 0.9849 - val_loss: 0.4472 - val_acc: 0.9290

# %% [markdown]
# ## Prediction
#
# This part of the notebook lets us inspect how well our classifier is doing by running the softmax classifier on the validation set and displaying the image + filename, and prediction along with the prediction confidence.

# %%
# Load the facenet model in case it hasn't been loaded yet
if model_enc is None:
    model_enc = load_model('facenet_keras.h5')

# %%
def predict_image(filename, model_enc, model_dec, plot=True):
    # load image in, extract face pixels, get embedding
    face_pixels = extract_face(filename, detector)
    
    
    if face_pixels is None:
        return -1
    
    image_x = np.asarray(face_pixels)
    
    if plot:
        pyplot.imshow(face_pixels)

        pyplot.title(filename)
        pyplot.show()
    #print("image shape", image_x.shape)
   
    face_pixels = (face_pixels - mean)/std
    face_pixels = expand_dims(face_pixels, axis=0)
    

    image_emb = get_embedding(model_enc, face_pixels)
    
    yhat = model_dec.predict(image_emb)
    
    # get_name 
    class_index = np.argmax(yhat[0])
    
    # Add one to match up with the directory names
    
    
    class_probability = yhat[0,class_index] * 100
    
    class_index = class_index+1
    #predict_names = out_encoder.inverse_transform(yhat_class)
    print('Predicted: %s (%.3f)' % (class_index, class_probability))
    #print('Expected: %s' % random_face_name[0])
    # plot for fun
    

    return class_index

# %%
path = 'data/Celeb1-A/1000/val/'
random_id = random.randint(1, 1000)

path = path  + str(random_id)


images = os.listdir(path)
random_image = random.choice(images)

filename = path + '/' + random_image

class_index = predict_image(filename, model_enc, model)

if class_index == random_id:
    print("Correct!")
else:
    print("Wrong!")
# Out:
# Predicted: 745 (50.994)
# Correct!

# %%
## Run prediction on 1000 randomly selected images from our dataset
## and see how well it does

total = 1000
correct = 0

for i in range(total):
    path = 'data/Celeb1-A/1000/val/'
    random_id = random.randint(1, 1000)

    path = path  + str(random_id)


    images = os.listdir(path)
    random_image = random.choice(images)

    filename = path + '/' + random_image

    class_index = predict_image(filename, model_enc, model, plot=False)

    if class_index == random_id:
        correct += 1
    
print("Accuracy: ", correct/total*100.)
# Out:
# Predicted: 144 (98.320)
# Predicted: 916 (16.977)
# Predicted: 857 (99.127)
# Predicted: 788 (98.282)
# Predicted: 841 (9.863)
# Predicted: 348 (98.828)
# Predicted: 395 (76.048)
# Predicted: 184 (98.185)
# Predicted: 643 (16.213)
# Predicted: 923 (98.742)
# Predicted: 965 (99.597)
# Predicted: 876 (95.278)
# Predicted: 670 (53.591)
# Predicted: 644 (98.171)
# Predicted: 651 (97.275)
# Predicted: 675 (97.025)
# Predicted: 563 (99.296)
# Predicted: 895 (95.603)
# Predicted: 840 (97.185)
# Predicted: 683 (87.696)
# Predicted: 331 (98.420)
# Predicted: 677 (83.797)
# Predicted: 69 (98.607)
# Predicted: 921 (98.767)
# Predicted: 160 (96.836)
# Predicted: 764 (98.610)
# Predicted: 83 (59.508)
# Predicted: 720 (89.893)
# Predicted: 144 (98.320)
# Predicted: 350 (78.473)
# Predicted: 332 (98.327)
# Predicted: 564 (97.087)
# Predicted: 264 (90.250)
# Predicted: 422 (99.306)
# Predicted: 523 (96.812)
# Predicted: 711 (90.289)
# Predicted: 949 (94.927)
# Predicted: 18 (91.957)
# Predicted: 822 (99.393)
# Predicted: 787 (65.428)
# Predicted: 447 (99.547)
# Predicted: 771 (96.156)
# Predicted: 169 (41.965)
# Predicted: 237 (86.088)
# Predicted: 706 (83.405)
# Predicted: 621 (90.122)
# Predicted: 266 (12.190)
# Predicted: 397 (94.344)
# Predicted: 565 (76.181)
# Predicted: 49 (97.718)
# Predicted: 381 (96.931)
# Predicted: 455 (68.445)
# Predicted: 213 (98.862)
# Predicted: 957 (98.453)
# Predicted: 619 (98.916)
# Predicted: 500 (89.129)
# Predicted: 931 (65.132)
# Predicted: 967 (99.575)
# Predicted: 550 (90.725)
# Predicted: 817 (58.510)
# Predicted: 299 (98.166)
# Predicted: 386 (93.762)
# Predicted: 580 (93.418)
# Predicted: 989 (18.409)
# Predicted: 940 (98.558)
# Predicted: 25 (99.223)
# Predicted: 776 (99.643)
# Predicted: 970 (99.225)
# Predicted: 818 (84.651)
# Predicted: 746 (97.151)
# Predicted: 964 (99.288)
# Predicted: 299 (98.166)
# Predicted: 91 (42.107)
# Predicted: 937 (88.919)
# Predicted: 540 (79.446)
# Predicted: 657 (35.779)
# Predicted: 967 (96.850)
# Predicted: 824 (99.383)
# Predicted: 707 (95.869)
# Predicted: 291 (98.857)
# Predicted: 704 (96.537)
# Predicted: 571 (98.844)
# Predicted: 585 (61.872)
# Predicted: 783 (96.250)
# Predicted: 306 (98.184)
# Predicted: 495 (99.078)
# Predicted: 639 (11.135)
# Predicted: 924 (96.167)
# Predicted: 11 (93.652)
# Predicted: 567 (95.554)
# Predicted: 431 (92.823)
# Predicted: 250 (98.719)
# Predicted: 873 (98.883)
# Predicted: 408 (17.928)
# Predicted: 988 (99.043)
# Predicted: 428 (95.815)
# Predicted: 507 (93.968)
# Predicted: 422 (97.861)
# Predicted: 262 (77.472)
# Predicted: 139 (96.824)
# Predicted: 844 (99.718)
# Predicted: 841 (97.397)
# Predicted: 306 (98.643)
# Predicted: 173 (99.379)
# Predicted: 376 (89.526)
# Predicted: 988 (43.185)
# Predicted: 922 (96.270)
# Predicted: 268 (99.272)
# Predicted: 179 (82.673)
# Predicted: 448 (99.338)
# Predicted: 201 (93.239)
# Predicted: 472 (95.748)
# Predicted: 347 (97.099)
# Predicted: 998 (41.499)
# Predicted: 306 (71.428)
# Predicted: 299 (96.698)
# Predicted: 636 (91.665)
# Predicted: 142 (99.264)
# Predicted: 128 (97.520)
# Predicted: 139 (96.824)
# Predicted: 334 (80.659)
# Predicted: 888 (87.019)
# Predicted: 319 (96.179)
# Predicted: 699 (71.215)
# Predicted: 295 (44.013)
# Predicted: 109 (74.309)
# Predicted: 103 (86.901)
# Predicted: 333 (95.013)
# Predicted: 674 (88.712)
# Predicted: 278 (96.319)
# Predicted: 169 (41.965)
# Predicted: 841 (97.828)
# Predicted: 569 (98.063)
# Predicted: 300 (92.733)
# Predicted: 31 (96.761)
# Predicted: 834 (99.465)
# Predicted: 677 (79.413)
# Predicted: 893 (93.316)
# Predicted: 519 (94.270)
# Predicted: 946 (99.091)
# Predicted: 635 (75.594)
# Predicted: 747 (48.512)
# Predicted: 275 (99.643)
# Predicted: 336 (99.474)
# Predicted: 707 (93.789)
# Predicted: 704 (93.840)
# Predicted: 772 (98.417)
# Predicted: 274 (43.148)
# Predicted: 247 (99.581)
# Predicted: 925 (98.026)
# Predicted: 812 (92.805)
# Predicted: 854 (21.716)
# Predicted: 822 (99.527)
# Predicted: 171 (99.524)
# Predicted: 392 (98.937)
# Predicted: 516 (98.316)
# Predicted: 544 (98.136)
# Predicted: 969 (92.685)
# Predicted: 446 (97.437)
# Predicted: 147 (97.802)
# Predicted: 772 (98.651)
# Predicted: 586 (96.010)
# Predicted: 790 (98.841)
# Predicted: 773 (94.545)
# Predicted: 771 (94.326)
# Predicted: 680 (20.797)
# Predicted: 652 (95.287)
# Predicted: 527 (94.890)
# Predicted: 316 (97.942)
# Predicted: 676 (92.045)
# Predicted: 35 (55.779)
# Predicted: 676 (13.079)
# Predicted: 210 (99.113)
# Predicted: 695 (95.058)
# Predicted: 366 (94.803)
# Predicted: 655 (91.219)
# Predicted: 788 (92.317)
# Predicted: 15 (97.828)
# Predicted: 918 (99.076)
# Predicted: 766 (96.414)
# Predicted: 713 (98.622)
# Predicted: 502 (98.877)
# Predicted: 425 (98.597)
# Predicted: 544 (97.156)
# Predicted: 334 (90.108)
# Predicted: 962 (92.792)
# Predicted: 549 (99.565)
# Predicted: 202 (89.696)
# Predicted: 643 (97.709)
# Predicted: 806 (86.051)
# Predicted: 19 (95.638)
# Predicted: 139 (91.270)
# Predicted: 461 (6.472)
# Predicted: 584 (3.990)
# Predicted: 930 (98.667)
# Predicted: 631 (98.663)
# Predicted: 287 (98.371)
# Predicted: 355 (89.506)
# Predicted: 579 (92.907)
# Predicted: 269 (99.221)
# Predicted: 62 (98.200)
# Predicted: 701 (98.930)
# Predicted: 395 (37.682)
# Predicted: 842 (99.030)
# Predicted: 896 (99.302)
# Predicted: 96 (99.409)
# Predicted: 214 (98.913)
# Predicted: 921 (99.743)
# Predicted: 593 (79.832)
# Predicted: 206 (98.815)
# Predicted: 749 (62.209)
# Predicted: 411 (75.712)
# Predicted: 924 (99.448)
# Predicted: 73 (96.925)
# Predicted: 317 (47.490)
# Predicted: 326 (98.622)
# Predicted: 840 (98.330)
# Predicted: 718 (83.665)
# Predicted: 707 (93.789)
# Predicted: 393 (98.339)
# Predicted: 14 (97.624)
# Predicted: 577 (96.759)
# Predicted: 38 (96.478)
# Predicted: 551 (98.624)
# Predicted: 36 (97.774)
# Predicted: 314 (41.683)
# Predicted: 144 (98.320)
# Predicted: 69 (98.503)
# Predicted: 5 (99.794)
# Predicted: 537 (70.837)
# Predicted: 326 (98.642)
# Predicted: 237 (86.088)
# Predicted: 688 (91.330)
# Predicted: 290 (99.508)
# Predicted: 103 (38.281)
# Predicted: 475 (96.719)
# Predicted: 851 (16.608)
# Predicted: 249 (69.427)
# Predicted: 409 (97.860)
# Predicted: 171 (96.107)
# Predicted: 506 (94.536)
# Predicted: 670 (92.685)
# Predicted: 955 (92.490)
# Predicted: 685 (95.775)
# Predicted: 286 (25.749)
# Predicted: 720 (71.943)
# Predicted: 553 (98.690)
# Predicted: 241 (26.272)
# Predicted: 212 (99.404)
# Predicted: 494 (98.223)
# Predicted: 535 (99.382)
# Predicted: 230 (83.801)
# Predicted: 984 (94.159)
# Predicted: 826 (98.865)
# Predicted: 431 (37.819)
# Predicted: 620 (98.452)
# Predicted: 639 (11.135)
# Predicted: 331 (98.420)
# Predicted: 914 (89.877)
# Predicted: 908 (92.011)
# Predicted: 771 (97.901)
# Predicted: 230 (97.327)
# Predicted: 495 (31.973)
# Predicted: 431 (92.823)
# Predicted: 374 (98.310)
# Predicted: 390 (83.992)
# Predicted: 414 (98.372)
# Predicted: 106 (98.335)
# Predicted: 241 (97.692)
# Predicted: 88 (96.703)
# Predicted: 287 (97.520)
# Predicted: 326 (98.642)
# Predicted: 27 (62.420)
# Predicted: 297 (97.124)
# Predicted: 675 (45.884)
# Predicted: 747 (89.884)
# Predicted: 815 (98.311)
# Predicted: 827 (98.528)
# Predicted: 205 (98.821)
# Predicted: 569 (98.198)
# Predicted: 537 (70.837)
# Predicted: 614 (12.698)
# Predicted: 551 (98.624)
# Predicted: 789 (99.539)
# Predicted: 444 (88.941)
# Predicted: 69 (97.055)
# Predicted: 333 (99.136)
# Predicted: 117 (97.407)
# Predicted: 472 (47.605)
# Predicted: 868 (89.972)
# Predicted: 31 (99.631)
# Predicted: 678 (97.505)
# Predicted: 390 (72.275)
# Predicted: 62 (98.200)
# Predicted: 418 (99.090)
# Predicted: 342 (93.497)
# Predicted: 535 (99.270)
# Predicted: 550 (99.494)
# Predicted: 734 (96.927)
# Predicted: 163 (99.682)
# Predicted: 51 (97.529)
# Predicted: 501 (98.838)
# Predicted: 941 (95.472)
# Predicted: 979 (97.690)
# Predicted: 920 (56.898)
# Predicted: 56 (99.631)
# Predicted: 112 (81.680)
# Predicted: 284 (80.713)
# Predicted: 934 (96.842)
# Predicted: 396 (92.928)
# Predicted: 514 (98.321)
# Predicted: 927 (91.147)
# Predicted: 423 (99.219)
# Predicted: 122 (99.653)
# Predicted: 30 (95.895)
# Predicted: 136 (37.171)
# Predicted: 383 (91.492)
# Predicted: 967 (93.742)
# Predicted: 214 (99.469)
# Predicted: 39 (36.087)
# Predicted: 911 (98.532)
# Predicted: 574 (99.256)
# Predicted: 198 (99.498)
# Predicted: 326 (98.642)
# Predicted: 369 (87.186)
# Predicted: 972 (98.334)
# Predicted: 262 (98.623)
# Predicted: 694 (17.180)
# Predicted: 232 (87.083)
# Predicted: 110 (95.033)
# Predicted: 554 (99.166)
# Predicted: 800 (96.450)
# Predicted: 620 (99.149)
# Predicted: 752 (90.496)
# Predicted: 367 (98.494)
# Predicted: 964 (99.353)
# Predicted: 797 (93.900)
# Predicted: 209 (97.710)
# Predicted: 985 (30.114)
# Predicted: 967 (98.331)
# Predicted: 835 (98.974)
# Predicted: 465 (9.230)
# Predicted: 100 (88.920)
# Predicted: 627 (10.655)
# Predicted: 121 (99.498)
# Predicted: 332 (95.926)
# Predicted: 691 (99.124)
# Predicted: 561 (79.464)
# Predicted: 92 (68.447)
# Predicted: 37 (15.075)
# Predicted: 739 (93.024)
# Predicted: 16 (96.179)
# Predicted: 273 (92.902)
# Predicted: 418 (85.842)
# Predicted: 267 (94.521)
# Predicted: 438 (94.892)
